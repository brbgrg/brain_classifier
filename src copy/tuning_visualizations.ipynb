# %%
from fetch_and_visualize import plot_train_val_curves, plot_train_val_curves_path

# %%
project_name = 'graph-classification-graphs_sc'
metrics = ['loss', 'accuracy', 'f1']

# %%
run_id = '4y6v9ufy'  
plot_train_val_curves(run_id, metrics, project_name=project_name, display_config=True)
# Out:
# Hyperparameters configuration:
# num_heads: 3
# optimizer: adam
# test_size: 0.3
# batch_size: 8
# num_epochs: 10
# in_channels: 6
# out_channels: 4
# random_state: 42
# weight_decay: 0.0001
# learning_rate: 0.01

# %%
run_id = '2803hxhf'
plot_train_val_curves(run_id, metrics, project_name=project_name, display_config=True)
# Out:
# Hyperparameters configuration:
# num_heads: 4
# optimizer: adam
# test_size: 0.3
# batch_size: 8
# num_epochs: 10
# in_channels: 6
# out_channels: 4
# random_state: 42
# weight_decay: 0
# learning_rate: 0.01

# %%
import os
# best model visualization

best_model_path = os.path.abspath('final_model_graphs_sc.pth')
plot_train_val_curves_path(best_model_path, metrics)
# Out:
# No history data found in file c:\Users\barbo\brain classifier repo\brain_classifier\src\final_model_graphs_sc.pth.

# %%
best_run_id = 'blufate1'
plot_train_val_curves(best_run_id, metrics, project_name=project_name, display_config=True)
# Out:
# Hyperparameters configuration:
